# %%
a1=0
a2=0
a3=0
b1=0
b2=0
b3=0
c1=0
c2=0
c3=0
var=0
jugador1=input('Jugador uno ingrese la celda: ')
if(jugador1=="a1"):
  a1=1
if(jugador1=="a2"):
  a2=1
if(jugador1=="a3"):
  a3=1
if(jugador1=="b1"):
  b1=1
if(jugador1=="b2"):
  b2=1
if(jugador1=="b3"):
  b3=1
if(jugador1=="c1"):
  c1=1
if(jugador1=="c2"):
  c2=1
if(jugador1=="c3"):
  c3=1

jugador2=input('Jugador dos ingrese la celda: ')
if(jugador2=="a1"):
  a1=2
if(jugador2=="a2"):
  a2=2
if(jugador2=="a3"):
  a3=2
if(jugador2=="b1"):
  b1=2
if(jugador2=="b2"):
  b2=2
if(jugador2=="b3"):
  b3=2
if(jugador2=="c1"):
  c1=2
if(jugador2=="c2"):
  c2=2
if(jugador2=="c3"):
  c3=2


jugador1=input('Jugador uno ingrese la celda: ')
if(jugador1=="a1"):
  a1=1
if(jugador1=="a2"):
  a2=1
if(jugador1=="a3"):
  a3=1
if(jugador1=="b1"):
  b1=1
if(jugador1=="b2"):
  b2=1
if(jugador1=="b3"):
  b3=1
if(jugador1=="c1"):
  c1=1
if(jugador1=="c2"):
  c2=1
if(jugador1=="c3"):
  c3=1


jugador2=input('Jugador dos ingrese la celda: ')
if(jugador2=="a1"):
  a1=2
if(jugador2=="a2"):
  a2=2
if(jugador2=="a3"):
  a3=2
if(jugador2=="b1"):
  b1=2
if(jugador2=="b2"):
  b2=2
if(jugador2=="b3"):
  b3=2
if(jugador2=="c1"):
  c1=2
if(jugador2=="c2"):
  c2=2
if(jugador2=="c3"):
  c3=2



jugador1=input('Jugador uno ingrese la celda: ')
if(jugador1=="a1"):
  a1=1
if(jugador1=="a2"):
  a2=1
if(jugador1=="a3"):
  a3=1
if(jugador1=="b1"):
  b1=1
if(jugador1=="b2"):
  b2=1
if(jugador1=="b3"):
  b3=1
if(jugador1=="c1"):
  c1=1
if(jugador1=="c2"):
  c2=1
if(jugador1=="c3"):
  c3=1


if((a1==1) and (a2==1)and(a3==1)):
  print("Gana jugador 1")
  var=1
if((a1==1) and (b2==1)and(c3==1)):
  print("Gana jugador 1")
  var=1
if((a2==1) and (b2==1)and(c2==1)):
  print("Gana jugador 1")
  var=1
if((b1==1) and (b2==1)and(b3==1)):
  print("Gana jugador 1")
  var=1
if((a3==1) and (b2==1)and(c1==1)):
  print("Gana jugador 1")
  var=1
if((a3==1) and (b3==1)and(c3==1)):
  print("Gana jugador 1")
  var=1
if((c1==1) and (c2==1)and(c3==1)):
  print("Gana jugador 1")
  var=1
if((a1==1) and (b1==1)and(c1==1)):
  print("Gana jugador 1")
  var=1

if(var==0):
  jugador2=input('Jugador dos ingrese la celda: ')
  if(jugador2=="a1"):
    a1=2
  elif(jugador2=="a2"):
    a2=2
  elif(jugador2=="a3"):
    a3=2
  elif(jugador2=="b1"):
    b1=2
  elif(jugador2=="b2"):
    b2=2
  elif(jugador2=="b3"):
    b3=2
  elif(jugador2=="c1"):
    c1=2
  elif(jugador2=="c2"):
    c2=2
  elif(jugador2=="c3"):
    c3=2

  if((a1==2) and (a2==2)and(a3==2)):
    print("Gana jugador 2")
    var=1
  elif((a1==2) and (b2==2)and(c3==2)):
    print("Gana jugador 2")
    var=1
  elif((a2==2) and (b2==2)and(c2==2)):
    print("Gana jugador 2")
    var=1
  elif((b1==2) and (b2==2)and(b3==2)):
    print("Gana jugador 2")
    var=1
  elif((a3==2) and (b2==2)and(c1==2)):
    print("Gana jugador 2")
    var=1
  elif((a3==2) and (b3==2)and(c3==2)):
    print("Gana jugador 2")
    var=1
  elif((c1==2) and (c2==2)and(c3==2)):
    print("Gana jugador 2")
    var=1
  elif((a1==2) and (b1==2)and(c1==2)):
    print("Gana jugador 2")
    var=1

elif(var==0):
  jugador1=input('Jugador uno ingrese la celda: ')
  if(jugador1=="a1"):
    a1=1
  elif(jugador1=="a2"):
    a2=1
  elif(jugador1=="a3"):
    a3=1
  elif(jugador1=="b1"):
    b1=1
  elif(jugador1=="b2"):
    b2=1
  elif(jugador1=="b3"):
    b3=1
  elif(jugador1=="c1"):
    c1=1
  elif(jugador1=="c2"):
    c2=1
  elif(jugador1=="c3"):
    c3=1

  if((a1==1) and (a2==1)and(a3==1)):
    print("Gana jugador 1")
    var=1
  elif((a1==1) and (b2==1)and(c3==1)):
    print("Gana jugador 1")
    var=1
  elif((a2==1) and (b2==1)and(c2==1)):
    print("Gana jugador 1")
    var=1
  elif((b1==1) and (b2==1)and(b3==1)):
    print("Gana jugador 1")
    var=1
  elif((a3==1) and (b2==1)and(c1==1)):
    print("Gana jugador 1")
    var=1
  elif((a3==1) and (b3==1)and(c3==1)):
    print("Gana jugador 1")
    var=1
  elif((c1==1) and (c2==1)and(c3==1)):
    print("Gana jugador 1")
    var=1
  elif((a1==1) and (b1==1)and(c1==1)):
    print("Gana jugador 1")
    var=1

elif(var==0):
  jugador2=input('Jugador dos ingrese la celda: ')
  if(jugador2=="a1"):
    a1=2
  elif(jugador2=="a2"):
    a2=2
  elif(jugador2=="a3"):
    a3=2
  elif(jugador2=="b1"):
    b1=2
  elif(jugador2=="b2"):
    b2=2
  elif(jugador2=="b3"):
    b3=2
  elif(jugador2=="c1"):
    c1=2
  elif(jugador2=="c2"):
    c2=2
  elif(jugador2=="c3"):
    c3=2

  if((a1==2) and (a2==2)and(a3==2)):
    print("Gana jugador 2")
    var=1
  elif((a1==2) and (b2==2)and(c3==2)):
    print("Gana jugador 2")
    var=1
  elif((a2==2) and (b2==2)and(c2==2)):
    print("Gana jugador 2")
    var=1
  elif((b1==2) and (b2==2)and(b3==2)):
    print("Gana jugador 2")
    var=1
  elif((a3==2) and (b2==2)and(c1==2)):
    print("Gana jugador 2")
    var=1
  elif((a3==2) and (b3==2)and(c3==2)):
    print("Gana jugador 2")
    var=1
  elif((c1==2) and (c2==2)and(c3==2)):
    print("Gana jugador 2")
    var=1
  elif((a1==2) and (b1==2)and(c1==2)):
    print("Gana jugador 2")
    var=1

elif(var==0):
  jugador1=input('Jugador uno ingrese la celda: ')
  if(jugador1=="a1"):
    a1=1
  elif(jugador1=="a2"):
    a2=1
  elif(jugador1=="a3"):
    a3=1
  elif(jugador1=="b1"):
    b1=1
  elif(jugador1=="b2"):
    b2=1
  elif(jugador1=="b3"):
    b3=1
  elif(jugador1=="c1"):
    c1=1
  elif(jugador1=="c2"):
    c2=1
  elif(jugador1=="c3"):
    c3=1

  if((a1==1) and (a2==1)and(a3==1)):
    print("Gana jugador 1")
    var=1
  elif((a1==1) and (b2==1)and(c3==1)):
    print("Gana jugador 1")
    var=1
  elif((a2==1) and (b2==1)and(c2==1)):
    print("Gana jugador 1")
    var=1
  elif((b1==1) and (b2==1)and(b3==1)):
    print("Gana jugador 1")
    var=1
  elif((a3==1) and (b2==1)and(c1==1)):
    print("Gana jugador 1")
    var=1
  elif((a3==1) and (b3==1)and(c3==1)):
    print("Gana jugador 1")
    var=1
  elif((c1==1) and (c2==1)and(c3==1)):
    print("Gana jugador 1")
    var=1
  elif((a1==1) and (b1==1)and(c1==1)):
    print("Gana jugador 1")
    var=1

else:
  print("Empate")
# Out:
# Jugador uno ingrese la celda: b2
# Jugador dos ingrese la celda: a1
# Jugador uno ingrese la celda: c1
# Jugador dos ingrese la celda: a2
# Jugador uno ingrese la celda: c2
# Jugador dos ingrese la celda: a3
# Gana jugador 2
